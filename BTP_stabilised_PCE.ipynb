# %%
import pandas as pd

# %%
df = pd.read_excel('Cleaned_Perovskite_Data2.xlsx')
print("The data is read")
# Out:
# The data is read

# %%
df = df.drop(["JV_forward_scan_PCE","JV_reverse_scan_PCE"], axis = 1)
print("columns are dropped")
# Out:
# columns are dropped

# %%
df.dropna(subset = ["Stabilised_performance_PCE", "Perovskite_composition_long_form"], inplace = True)
print("rows are dropped")
# Out:
# rows are dropped

# %%
df.shape
# Out:
# (3439, 21)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy = "median")
df_num = df.drop("Perovskite_composition_long_form", axis = 1)
imputer.fit(df_num)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([1.00000000e+00, 1.00000000e+00, 1.00000000e+02, 1.00000000e+02,
#        1.06600000e+00, 2.15450000e+01, 7.34000000e-01, 1.05900000e+00,
#        2.18000000e+01, 7.10000000e-01, 1.57000000e+01, 1.18843128e-01,
#        1.57000000e+01, 2.07000000e+01, 1.00000000e+00, 5.00000000e+02,
#        1.67900000e+01, 8.30000000e+01, 1.00000000e+00, 0.00000000e+00])

# %%
X = imputer.transform(df_num)
print("transformation done")
# Out:
# transformation done

# %%
df_tr = pd.DataFrame(X, columns = df_num.columns)
print("df_tr prepared")
# Out:
# df_tr prepared

# %%
df_cat = df[["Perovskite_composition_long_form"]]

df_cat.head(10)
# Out:
#     Perovskite_composition_long_form
# 15                            MAPbI3
# 16                            MAPbI3
# 128                           FAPbI3
# 180                           FAPbI3
# 181        Cs0.05FA0.95PbBr0.15I2.85
# 182            Cs0.1FA0.9PbBr0.3I2.7
# 183        Cs0.15FA0.85PbBr0.45I2.55
# 184            Cs0.2FA0.8PbBr0.6I2.4
# 208                           MAPbI3
# 209                           MAPbI3

# %%
df_tr.reset_index(drop = True, inplace = True)
df_cat.reset_index(drop = True, inplace = True)

df_combined = pd.concat([df_tr, df_cat], axis = 1)
print("concantenated")
# Out:
# concantenated

# %%
df_combined.head()
# Out:
#    Perovskite_deposition_number_of_deposition_steps  \
# 0                                               1.0
# 1                                               1.0
# 2                                               1.0
# 3                                               1.0
# 4                                               1.0
#
#    JV_average_over_n_number_of_cells  JV_light_intensity  JV_scan_speed  \
# 0                                1.0               100.0          100.0
# 1                                1.0               100.0          100.0
# 2                                1.0               100.0          100.0
# 3                                1.0               100.0          100.0
# 4                                1.0               100.0          100.0
#
#    JV_reverse_scan_Voc  JV_reverse_scan_Jsc  JV_reverse_scan_FF  \
# 0                0.850                18.23               0.810
# 1                0.830                14.44               0.780
# ...

# %%
df_combined.to_excel('stabilised_performance_PCE_dataset.xlsx', index = False)
print("the dataset is saved to excel sheet")
# Out:
# the dataset is saved to excel sheet
