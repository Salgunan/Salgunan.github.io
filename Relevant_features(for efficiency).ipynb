# %%
import pandas as pd

# %%
df = pd.read_excel('Relevant_features.xlsx')
print("excel file is read")
# Out:
# excel file is read

# %%
df.drop(['Stability_PCE_initial_value'],axis = 1, inplace = True)

# %%
df
# Out:
#        JV_reverse_scan_Voc  JV_reverse_scan_Jsc  JV_reverse_scan_FF  \
# 0                    0.002                0.220               0.570
# 1                    0.120                0.490               0.250
# 2                    0.135                3.690               0.260
# 3                    0.227                1.320               0.410
# 4                    0.190                1.570               0.340
# ...                    ...                  ...                 ...
# 43393                1.112               24.915               0.785
# 43394                1.080               23.950               0.765
# 43395                1.109               24.015               0.799
# 43396                1.050               24.141               0.695
# 43397                1.037               22.547               0.724
#
#        JV_reverse_scan_PCE  JV_forward_scan_Voc  JV_forward_scan_Jsc  \
# 0                     0.00                  NaN                  NaN
# ...

# %%
df.describe()
# Out:
#        JV_reverse_scan_Voc  JV_reverse_scan_Jsc  JV_reverse_scan_FF  \
# count         40428.000000         40462.000000        40277.000000
# mean              0.963553            17.944502            0.651088
# std               0.183323             5.545413            0.127131
# min               0.000000             0.000000            0.000000
# 25%               0.900000            15.830000            0.592000
# 50%               1.000000            19.650000            0.682000
# 75%               1.070000            21.770000            0.740000
# max               4.050000           144.100000            5.000000
#
#        JV_reverse_scan_PCE  JV_forward_scan_Voc  JV_forward_scan_Jsc  \
# count         41580.000000          9232.000000          9249.000000
# mean             12.127840             0.976204            18.952252
# std               5.315975             0.197030             5.068771
# min               0.000000             0.000000             0.010000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43398 entries, 0 to 43397
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   JV_reverse_scan_Voc               40428 non-null  float64
#  1   JV_reverse_scan_Jsc               40462 non-null  float64
#  2   JV_reverse_scan_FF                40277 non-null  float64
#  3   JV_reverse_scan_PCE               41580 non-null  float64
#  4   JV_forward_scan_Voc               9232 non-null   float64
#  5   JV_forward_scan_Jsc               9249 non-null   float64
#  6   JV_forward_scan_FF                9199 non-null   float64
#  7   JV_forward_scan_PCE               9421 non-null   float64
#  8   JV_default_PCE                    42370 non-null  float64
#  9   Stabilised_performance_PCE        3439 non-null   float64
#  10  EQE_integrated_Jsc                5595 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# JV_reverse_scan_Voc                  2970
# JV_reverse_scan_Jsc                  2936
# JV_reverse_scan_FF                   3121
# JV_reverse_scan_PCE                  1818
# JV_forward_scan_Voc                 34166
# JV_forward_scan_Jsc                 34149
# JV_forward_scan_FF                  34199
# JV_forward_scan_PCE                 33977
# JV_default_PCE                       1028
# Stabilised_performance_PCE          39959
# EQE_integrated_Jsc                  37803
# Stability_time_total_exposure       35993
# Stability_PCE_end_of_experiment     36022
# Stability_PCE_T80                   41559
# Perovskite_composition_long_form       63
# dtype: int64

# %%
df.nunique()
# Out:
# JV_reverse_scan_Voc                 1191
# JV_reverse_scan_Jsc                 3850
# JV_reverse_scan_FF                   742
# JV_reverse_scan_PCE                 2335
# JV_forward_scan_Voc                  774
# JV_forward_scan_Jsc                 2253
# JV_forward_scan_FF                   627
# JV_forward_scan_PCE                 1972
# JV_default_PCE                      2335
# Stabilised_performance_PCE          1001
# EQE_integrated_Jsc                  1279
# Stability_time_total_exposure        452
# Stability_PCE_end_of_experiment      839
# Stability_PCE_T80                    494
# Perovskite_composition_long_form    2238
# dtype: int64

# %%
df_numeric = df.select_dtypes(include = 'number')
df_numeric.corr()
# Out:
#                                  JV_reverse_scan_Voc  JV_reverse_scan_Jsc  \
# JV_reverse_scan_Voc                         1.000000             0.396239
# JV_reverse_scan_Jsc                         0.396239             1.000000
# JV_reverse_scan_FF                          0.526231             0.480227
# JV_reverse_scan_PCE                         0.601405             0.792943
# JV_forward_scan_Voc                         0.757450             0.292183
# JV_forward_scan_Jsc                         0.359474             0.947330
# JV_forward_scan_FF                          0.347787             0.429541
# JV_forward_scan_PCE                         0.523787             0.743956
# JV_default_PCE                              0.604563             0.798684
# Stabilised_performance_PCE                  0.315527             0.733751
# EQE_integrated_Jsc                          0.055878             0.897878
# Stability_time_total_exposure               0.030846            -0.009484
# ...

# %%
df_numeric.corr()['EQE_integrated_Jsc']
# Out:
# JV_reverse_scan_Voc                0.055878
# JV_reverse_scan_Jsc                0.897878
# JV_reverse_scan_FF                 0.364848
# JV_reverse_scan_PCE                0.778689
# JV_forward_scan_Voc                0.181276
# JV_forward_scan_Jsc                0.866505
# JV_forward_scan_FF                 0.301646
# JV_forward_scan_PCE                0.746553
# JV_default_PCE                     0.776107
# Stabilised_performance_PCE         0.801941
# EQE_integrated_Jsc                 1.000000
# Stability_time_total_exposure     -0.006976
# Stability_PCE_end_of_experiment   -0.011320
# Stability_PCE_T80                  0.107881
# Name: EQE_integrated_Jsc, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df_numeric.corr(), annot = True)
plt.rcParams['figure.figsize'] = (20,7)
plt.show()
print("plotted")
# Out:
# plotted

# %%
df.columns
# Out:
# Index(['JV_reverse_scan_Voc', 'JV_reverse_scan_Jsc', 'JV_reverse_scan_FF',
#        'JV_reverse_scan_PCE', 'JV_forward_scan_Voc', 'JV_forward_scan_Jsc',
#        'JV_forward_scan_FF', 'JV_forward_scan_PCE', 'JV_default_PCE',
#        'Stabilised_performance_PCE', 'EQE_integrated_Jsc',
#        'Stability_time_total_exposure', 'Stability_PCE_end_of_experiment',
#        'Stability_PCE_T80', 'Perovskite_composition_long_form'],
#       dtype='object')

# %%
#useful for outliers;
df_numeric.boxplot(figsize = (25,8))
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# <Axes: >

# %%
null_counts = df.isnull().sum()
total_len = len(df)
null_percentage = null_counts/total_len*100
#null_df = pd.dataframe({'Column_name':null_counts.index, 'null_percentage':})
for idx, col in enumerate(df):    
    print(f"{idx}. {col}  null percentage is :{null_percentage[col]:.2f}%")
# Out:
# 0. JV_reverse_scan_Voc  null percentage is :6.84%
# 1. JV_reverse_scan_Jsc  null percentage is :6.77%
# 2. JV_reverse_scan_FF  null percentage is :7.19%
# 3. JV_reverse_scan_PCE  null percentage is :4.19%
# 4. JV_forward_scan_Voc  null percentage is :78.73%
# 5. JV_forward_scan_Jsc  null percentage is :78.69%
# 6. JV_forward_scan_FF  null percentage is :78.80%
# 7. JV_forward_scan_PCE  null percentage is :78.29%
# 8. JV_default_PCE  null percentage is :2.37%
# 9. Stabilised_performance_PCE  null percentage is :92.08%
# 10. EQE_integrated_Jsc  null percentage is :87.11%
# 11. Stability_time_total_exposure  null percentage is :82.94%
# 12. Stability_PCE_end_of_experiment  null percentage is :83.00%
# 13. Stability_PCE_T80  null percentage is :95.76%
# 14. Perovskite_composition_long_form  null percentage is :0.15%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43398 entries, 0 to 43397
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   JV_reverse_scan_Voc               40428 non-null  float64
#  1   JV_reverse_scan_Jsc               40462 non-null  float64
#  2   JV_reverse_scan_FF                40277 non-null  float64
#  3   JV_reverse_scan_PCE               41580 non-null  float64
#  4   JV_forward_scan_Voc               9232 non-null   float64
#  5   JV_forward_scan_Jsc               9249 non-null   float64
#  6   JV_forward_scan_FF                9199 non-null   float64
#  7   JV_forward_scan_PCE               9421 non-null   float64
#  8   JV_default_PCE                    42370 non-null  float64
#  9   Stabilised_performance_PCE        3439 non-null   float64
#  10  EQE_integrated_Jsc                5595 non-null   float64
# ...

# %%
# %matplotlib inline   
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# imput with mode for categorical column.
mode_val = df['Perovskite_composition_long_form'].mode()[0]
df['Perovskite_composition_long_form'].fillna(mode_val, inplace=True)
print("imputed with mode")
# Out:
# imputed with mode
# /var/folders/gt/c1f87xs918l8xhksttwhlqzm0000gn/T/ipykernel_50820/1732481889.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Perovskite_composition_long_form'].fillna(mode_val, inplace=True)

# %%
df.dropna(subset = ['JV_forward_scan_PCE'], inplace = True)
print("dropping null values is done")
# Out:
# dropping null values is done

# %%
df.dropna(subset = ['JV_reverse_scan_PCE'],inplace = True)
print("null entries for output labels are dropped")
# Out:
# null entries for output labels are dropped

# %%
df1 = df.copy()

# %%
df.dropna(subset = ['Stabilised_performance_PCE'],inplace = True)
print("null entries for output labels are dropped")
# Out:
# null entries for output labels are dropped

# %%
df.isnull().sum()
# Out:
# JV_reverse_scan_Voc                    9
# JV_reverse_scan_Jsc                   10
# JV_reverse_scan_FF                    10
# JV_reverse_scan_PCE                    0
# JV_forward_scan_Voc                   81
# JV_forward_scan_Jsc                   81
# JV_forward_scan_FF                    82
# JV_forward_scan_PCE                    0
# JV_default_PCE                         0
# Stabilised_performance_PCE             0
# EQE_integrated_Jsc                   688
# Stability_time_total_exposure        870
# Stability_PCE_end_of_experiment      875
# Stability_PCE_T80                   1452
# Perovskite_composition_long_form       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1613 entries, 15 to 43343
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   JV_reverse_scan_Voc               1604 non-null   float64
#  1   JV_reverse_scan_Jsc               1603 non-null   float64
#  2   JV_reverse_scan_FF                1603 non-null   float64
#  3   JV_reverse_scan_PCE               1613 non-null   float64
#  4   JV_forward_scan_Voc               1532 non-null   float64
#  5   JV_forward_scan_Jsc               1532 non-null   float64
#  6   JV_forward_scan_FF                1531 non-null   float64
#  7   JV_forward_scan_PCE               1613 non-null   float64
#  8   JV_default_PCE                    1613 non-null   float64
#  9   Stabilised_performance_PCE        1613 non-null   float64
#  10  EQE_integrated_Jsc                925 non-null    float64
# ...

# %%
df_numeric = df.select_dtypes(include = ['number'])
df_numeric.corr()
# Out:
#                                  JV_reverse_scan_Voc  JV_reverse_scan_Jsc  \
# JV_reverse_scan_Voc                         1.000000             0.206352
# JV_reverse_scan_Jsc                         0.206352             1.000000
# JV_reverse_scan_FF                          0.308480             0.287246
# JV_reverse_scan_PCE                         0.398970             0.796716
# JV_forward_scan_Voc                         0.853417             0.248712
# JV_forward_scan_Jsc                         0.246567             0.926734
# JV_forward_scan_FF                          0.239182             0.331251
# JV_forward_scan_PCE                         0.355640             0.753271
# JV_default_PCE                              0.346664             0.762826
# Stabilised_performance_PCE                  0.346664             0.762826
# EQE_integrated_Jsc                         -0.055835             0.943004
# Stability_time_total_exposure               0.052877             0.060919
# ...

# %%
df.shape
# Out:
# (1613, 15)

# %%
df.drop('EQE_integrated_Jsc', axis = 1, inplace = True)

# %%
df.to_excel('Relevant_features2.xlsx', index = False)
print("Saved to excel sheet")
# Out:
# Saved to excel sheet
